# %% [markdown]
# # Youtube Transcripts
#
# This code uses a youtube transcriber library. Reference for that and how to install it yourself is below:
# https://github.com/jdepoix/youtube-transcript-api

# %% [markdown]
# ## Install relevant libraries
# if you get any messages like `ModuleNotFoundError: No module named 'youtube_transcript_api'`
#
# simply run `! pip install <package_name>`

# %%
#! pip install youtube_transcript_api

# %% [markdown]
# ## Get youtube video id's
# These are store in a google sheet

# %%
import pandas as pd
import numpy as np
import gspread
from oauth2client.service_account import ServiceAccountCredentials
from datetime import datetime, timezone
import pytz

#transcriptions
from youtube_transcript_api import YouTubeTranscriptApi as yt

#writing to aws
import json
import boto3

# %%
def authenticate_gsheet(gsheet_json_key, sheet_name):
    
    SCOPE = ['https://spreadsheets.google.com/feeds', 'https://www.googleapis.com/auth/drive']

    # use creds to create a client to interact with the Google Drive API
    creds = ServiceAccountCredentials.from_json_keyfile_name(gsheet_json_key, SCOPE)
    gc = gspread.authorize(creds)

    # ensure you share the spreadsheet with the project service account
    # the email you share it with can be found in the json key
    sh = gc.open(sheet_name).sheet1
    return sh

# %%
def import_gsheet(sheet):
    """
    given an instance of a gsheet, import it into a dataframe and return dataframe
    """
    data = sheet.get_all_values()
    df = pd.DataFrame.from_records(data)
    new_header = df.iloc[0] #grab the first row for the header
    df = df[1:] #take the data less the header row
    df.columns = new_header #set the header row as the df header
    return df

# %% [markdown]
# ## Get the transcript for each video

# %%
def get_text(transcript):
    """
    Given the dictionary of text, start, duration...extract JUST the string
    returns: the transcript as a string
    """
    text = ''
    for t in transcript:
        text += t['text'] + ' '

    return text

def get_duration_seconds(transcript):
    """
    INPUT: the dictionary of text, start, duration
    RETURNS: the length of the press conference
    """
    last_transcription = list(transcript)[-1]['start']
    duration = list(transcript)[-1]['duration']
    
    return last_transcription + duration

# %% [markdown]
# # Get all past transcripts
# This only has to be done once, and then it will be a daily task

# %%
#import the googlsheet into a dataframe
df = import_gsheet(sh)

#get the columns required
df = df[['date', 
         'link', 
         'id', 
        ]]

#add new columns/keys
df['duration_seconds']=0
df['transcript']=''
df['text']=''

temp_dict = df.to_dict(orient = 'records')#[STATE+'_id']
transcripts_dict = {}

for item in temp_dict:
    date = item.pop('date')
    transcripts_dict[date] = item
    
#transcripts_dict
# Out:
# {'20210617': {'link': 'https://www.youtube.com/watch?v=cItoaypG3zA',
#   'id': 'cItoaypG3zA',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210618': {'link': 'https://www.youtube.com/watch?v=H5oadwexEc4',
#   'id': 'H5oadwexEc4',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210619': {'link': 'https://www.youtube.com/watch?v=2RLfKycplrk',
#   'id': '2RLfKycplrk',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210620': {'link': 'https://www.youtube.com/watch?v=UZhRxCSwOqo',
#   'id': 'UZhRxCSwOqo',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210621': {'link': 'https://www.youtube.com/watch?v=f1XzcYnzWYI',
#   'id': 'f1XzcYnzWYI',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210622': {'link': 'https://www.youtube.com/watch?v=Hb0AlfE8BYk',
#   'id': 'Hb0AlfE8BYk',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210623': {'link': 'https://www.youtube.com/watch?v=fHg-sqMF3oA',
#   'id': 'fHg-sqMF3oA',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210624': {'link': 'https://www.youtube.com/watch?v=_SyzWqiI1w0',
#   'id': '_SyzWqiI1w0',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210625': {'link': 'https://www.youtube.com/watch?v=MkGwTbr_4N4',
#   'id': 'MkGwTbr_4N4',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210626': {'link': 'https://www.youtube.com/watch?v=WKr8XhxfAeM',
#   'id': 'WKr8XhxfAeM',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210627': {'link': 'https://www.youtube.com/watch?v=J3p9wpyHtKM',
#   'id': 'J3p9wpyHtKM',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210628': {'link': 'https://www.youtube.com/watch?v=QMog1CXrlEU',
#   'id': 'QMog1CXrlEU',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210629': {'link': 'https://www.youtube.com/watch?v=hBe9xC8z3iQ',
#   'id': 'hBe9xC8z3iQ',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210630': {'link': 'https://www.youtube.com/watch?v=z1wqP8ERpaw',
#   'id': 'z1wqP8ERpaw',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210701': {'link': 'https://www.youtube.com/watch?v=VEKL80gn1DY&t=32s',
#   'id': 'VEKL80gn1DY',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210702': {'link': 'https://www.youtube.com/watch?v=SI8OuUf-9B0&t=17s',
#   'id': 'SI8OuUf-9B0',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210703': {'link': 'https://www.youtube.com/watch?v=VYGs32vxm2k',
#   'id': 'VYGs32vxm2k',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210704': {'link': 'https://www.youtube.com/watch?v=XpdSqtdPT3c',
#   'id': 'XpdSqtdPT3c',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210705': {'link': 'https://www.youtube.com/watch?v=fbT7e_tYV1A&t=5s',
#   'id': 'fbT7e_tYV1A',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210706': {'link': 'https://www.youtube.com/watch?v=EIkH5VHky1c&t=349s',
#   'id': 'EIkH5VHky1c',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210707': {'link': 'https://www.youtube.com/watch?v=y2PU1MfEkgo&t=3s',
#   'id': 'y2PU1MfEkgo',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210708': {'link': 'https://www.youtube.com/watch?v=UcBi5RdMGfw&t=12s',
#   'id': 'UcBi5RdMGfw',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210709': {'link': 'https://www.youtube.com/watch?v=S77u-GXSyy0',
#   'id': 'S77u-GXSyy0',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210710': {'link': 'https://www.youtube.com/watch?v=XttK2JFDSHo&t=27s',
#   'id': 'XttK2JFDSHo',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210711': {'link': 'https://www.youtube.com/watch?v=pAxEm5kSIsM',
#   'id': 'pAxEm5kSIsM',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210712': {'link': 'https://www.youtube.com/watch?v=F9byDzTQAR0',
#   'id': 'F9byDzTQAR0',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210713': {'link': 'https://www.youtube.com/watch?v=zQr-0vyyrrU',
#   'id': 'zQr-0vyyrrU',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210714': {'link': 'https://www.youtube.com/watch?v=i5znaJdsW34',
#   'id': 'i5znaJdsW34',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210715': {'link': 'https://www.youtube.com/watch?v=gnjHQ9WgXMI',
#   'id': 'gnjHQ9WgXMI',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210716': {'link': 'https://www.youtube.com/watch?v=K_mnXZS1SYI',
#   'id': 'K_mnXZS1SYI',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210717': {'link': 'https://www.youtube.com/watch?v=HMVRsPGTaks',
#   'id': 'HMVRsPGTaks',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210718': {'link': 'n/a',
#   'id': 'n/a',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210719': {'link': 'https://www.youtube.com/watch?v=fYmo1W_sqZo',
#   'id': 'fYmo1W_sqZo',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210720': {'link': 'https://www.youtube.com/watch?v=_crm08Hty1Q',
#   'id': '_crm08Hty1Q',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210721': {'link': 'https://www.youtube.com/watch?v=f3w9VwDtUAw',
#   'id': 'f3w9VwDtUAw',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210722': {'link': 'https://www.youtube.com/watch?v=Qpe1zZpJsOw',
#   'id': 'Qpe1zZpJsOw',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210723': {'link': 'https://www.youtube.com/watch?v=zVNDPoIFlEU&t=24s',
#   'id': 'zVNDPoIFlEU',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210724': {'link': 'https://www.youtube.com/watch?v=7MVVJeY31bg',
#   'id': '7MVVJeY31bg',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210725': {'link': 'https://www.youtube.com/watch?v=N-k9m9hKP5o',
#   'id': 'N-k9m9hKP5o',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210726': {'link': 'https://www.youtube.com/watch?v=LcsWtmLPBmc',
#   'id': 'LcsWtmLPBmc',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210727': {'link': 'https://www.youtube.com/watch?v=yvcQMdx80p4',
#   'id': 'yvcQMdx80p4',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210728': {'link': 'https://www.youtube.com/watch?v=tweEsZF33GE',
#   'id': 'tweEsZF33GE',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210729': {'link': 'https://www.youtube.com/watch?v=I6YLt4SJbfE',
#   'id': 'I6YLt4SJbfE',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210730': {'link': 'https://www.youtube.com/watch?v=BKPC8m3Gz0E&t=58s',
#   'id': 'BKPC8m3Gz0E',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210731': {'link': 'https://www.youtube.com/watch?v=eI3tOKo9SgU',
#   'id': 'eI3tOKo9SgU',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210801': {'link': 'https://www.youtube.com/watch?v=QoZF3k2d-Ss',
#   'id': 'QoZF3k2d-Ss',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210802': {'link': 'https://www.youtube.com/watch?v=x47uI5k_0m4',
#   'id': 'x47uI5k_0m4',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210803': {'link': 'https://www.youtube.com/watch?v=A0LDikJX8Rg&t=464s',
#   'id': 'A0LDikJX8Rg',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210804': {'link': 'https://www.youtube.com/watch?v=O42daj7p2C0',
#   'id': 'O42daj7p2C0',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210805': {'link': 'https://www.youtube.com/watch?v=NbVrDjff5bk',
#   'id': 'NbVrDjff5bk',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210806': {'link': 'https://www.youtube.com/watch?v=ATFb8Z8r32A',
#   'id': 'ATFb8Z8r32A',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210807': {'link': 'https://www.youtube.com/watch?v=UX5I3qb3LzI',
#   'id': 'UX5I3qb3LzI',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210808': {'link': 'https://www.youtube.com/watch?v=2Sty2sqvAvA',
#   'id': '2Sty2sqvAvA',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210809': {'link': '',
#   'id': '',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210810': {'link': '',
#   'id': '',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210811': {'link': '',
#   'id': '',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210812': {'link': '',
#   'id': '',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210813': {'link': '',
#   'id': '',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210814': {'link': '',
#   'id': '',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210815': {'link': '',
#   'id': '',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210816': {'link': '',
#   'id': '',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210817': {'link': '',
#   'id': '',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210818': {'link': '',
#   'id': '',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210819': {'link': '',
#   'id': '',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210820': {'link': '',
#   'id': '',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210821': {'link': '',
#   'id': '',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210822': {'link': '',
#   'id': '',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210823': {'link': '',
#   'id': '',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210824': {'link': '',
#   'id': '',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210825': {'link': '',
#   'id': '',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210826': {'link': '',
#   'id': '',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210827': {'link': '',
#   'id': '',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210828': {'link': '',
#   'id': '',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210829': {'link': '',
#   'id': '',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210830': {'link': '',
#   'id': '',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''},
#  '20210831': {'link': '',
#   'id': '',
#   'duration_seconds': 0,
#   'transcript': '',
#   'text': ''}}

# %% [markdown]
# This piece of code iterates over the youtube id's and gets their corresponding:
# - transcript
# - duration
# - text (1 big string i.e. transcript without timestamps)
#
# If there is an error (e.g. now video found or their are no captions for the video then it will set the values as "error"

# %%
for date in transcripts_dict.keys():
    try:
        video_id = transcripts_dict[date]['id']
        #print("processing:",date, video_id)
        transcript = yt.get_transcript(video_id)
        duration = get_duration_seconds(transcript)
        text = get_text(transcript)
        
    except:
        print("An exception occurred for {}".format(date, video_id))
        transcript='error'
        duration = np.nan #null
        text='error'      
        
    #store the transcript dict in a dic
    transcripts_dict[date]['duration_seconds'] = duration
    transcripts_dict[date]['transcript'] = transcript
    transcripts_dict[date]['text'] = text
# Out:
# processing: 20210617 cItoaypG3zA
# processing: 20210618 H5oadwexEc4
# processing: 20210619 2RLfKycplrk
# processing: 20210620 UZhRxCSwOqo
# processing: 20210621 f1XzcYnzWYI
# processing: 20210622 Hb0AlfE8BYk
# processing: 20210623 fHg-sqMF3oA
# processing: 20210624 _SyzWqiI1w0
# processing: 20210625 MkGwTbr_4N4
# processing: 20210626 WKr8XhxfAeM
# processing: 20210627 J3p9wpyHtKM
# processing: 20210628 QMog1CXrlEU
# processing: 20210629 hBe9xC8z3iQ
# processing: 20210630 z1wqP8ERpaw
# processing: 20210701 VEKL80gn1DY
# processing: 20210702 SI8OuUf-9B0
# processing: 20210703 VYGs32vxm2k
# processing: 20210704 XpdSqtdPT3c
# processing: 20210705 fbT7e_tYV1A
# processing: 20210706 EIkH5VHky1c
# processing: 20210707 y2PU1MfEkgo
# processing: 20210708 UcBi5RdMGfw
# processing: 20210709 S77u-GXSyy0
# processing: 20210710 XttK2JFDSHo
# processing: 20210711 pAxEm5kSIsM
# processing: 20210712 F9byDzTQAR0
# processing: 20210713 zQr-0vyyrrU
# processing: 20210714 i5znaJdsW34
# processing: 20210715 gnjHQ9WgXMI
# processing: 20210716 K_mnXZS1SYI
# processing: 20210717 HMVRsPGTaks
# processing: 20210718 n/a
# An exception occurred for 20210718
# processing: 20210719 fYmo1W_sqZo
# processing: 20210720 _crm08Hty1Q
# processing: 20210721 f3w9VwDtUAw
# processing: 20210722 Qpe1zZpJsOw
# processing: 20210723 zVNDPoIFlEU
# processing: 20210724 7MVVJeY31bg
# processing: 20210725 N-k9m9hKP5o
# processing: 20210726 LcsWtmLPBmc
# processing: 20210727 yvcQMdx80p4
# processing: 20210728 tweEsZF33GE
# processing: 20210729 I6YLt4SJbfE
# processing: 20210730 BKPC8m3Gz0E
# processing: 20210731 eI3tOKo9SgU
# processing: 20210801 QoZF3k2d-Ss
# processing: 20210802 x47uI5k_0m4
# processing: 20210803 A0LDikJX8Rg
# processing: 20210804 O42daj7p2C0
# processing: 20210805 NbVrDjff5bk
# processing: 20210806 ATFb8Z8r32A
# processing: 20210807 UX5I3qb3LzI
# processing: 20210808 2Sty2sqvAvA
# An exception occurred for 20210808
# processing: 20210809
# An exception occurred for 20210809
# processing: 20210810
# An exception occurred for 20210810
# processing: 20210811
# An exception occurred for 20210811
# processing: 20210812
# An exception occurred for 20210812
# processing: 20210813
# An exception occurred for 20210813
# processing: 20210814
# An exception occurred for 20210814
# processing: 20210815
# An exception occurred for 20210815
# processing: 20210816
# An exception occurred for 20210816
# processing: 20210817
# An exception occurred for 20210817
# processing: 20210818
# An exception occurred for 20210818
# processing: 20210819
# An exception occurred for 20210819
# processing: 20210820
# An exception occurred for 20210820
# processing: 20210821
# An exception occurred for 20210821
# processing: 20210822
# An exception occurred for 20210822
# processing: 20210823
# An exception occurred for 20210823
# processing: 20210824
# An exception occurred for 20210824
# processing: 20210825
# An exception occurred for 20210825
# processing: 20210826
# An exception occurred for 20210826
# processing: 20210827
# An exception occurred for 20210827
# processing: 20210828
# An exception occurred for 20210828
# processing: 20210829
# An exception occurred for 20210829
# processing: 20210830
# An exception occurred for 20210830
# processing: 20210831
# An exception occurred for 20210831

# %% [markdown]
# ### Write to AWS S3 bucket
# Next we write to aws S3:
# - each day gets its own transcription text
# - and then there is one giant .json file with text, links, durations etc

# %%
s3 = boto3.resource('s3')
STATE = 'nsw'
#DATE = '20210807'

json_object = (bytes(json.dumps(transcripts_dict).encode('UTF-8')))
BUCKET_NAME = 'covid19-au-press-conferences'
json_key = STATE+'/json/'+STATE+'_transcriptions.json'

s3_client = boto3.client('s3',
    aws_access_key_id=ACCESS_KEY,
    aws_secret_access_key=SECRET_KEY,)


#dump the transcript dictionary to s3 as a json file
s3_client.put_object(Body=json_object,
                     Bucket=BUCKET_NAME, 
                     Key=json_key, 
                     ContentType='application/json') #MIME type


#write each individual transcriptions as a new text file
for date in transcripts_dict.keys():
    print(date)
    txt_object = transcripts_dict[date]['text']#.encode('ascii')
    txt_key = STATE+'/text/'+date+'_'+STATE+'_press_conference.txt'

    s3_client.put_object(Body=txt_object,
                         Bucket=BUCKET_NAME, 
                         Key=txt_key,
                         ContentType='text/plain') #MIME type

# %% [markdown]
# ## Defining some functions to interact with aws S3

# %%
def download_s3_file_to_local(bucket_name, key, local_file):
    """
    using your aws access key (configures in aws cli) this function
    downloads the file at bucket_name/key into local_file
    
    """
    import boto3
    import botocore

    s3 = boto3.resource('s3')

    try:
        s3.Bucket(bucket_name).download_file(key, local_file)
    except botocore.exceptions.ClientError as e:
        if e.response['Error']['Code'] == "404":
            print("The object does not exist.")
        else:
            raise
            

def download_s3_file_to_memory(bucket_name, key):
    s3_client = boto3.client('s3')
    s3_response_object = s3_client.get_object(Bucket=bucket_name, Key=key)
    object_content = s3_response_object['Body'].read()
    return object_content


def add_file_to_s3(bucket_name, key, txt_object):
    """
    Writes a string to a bucket/key
    depending on format of key will write as txt or json    
    """
    print("starting up S3 client...")
    s3_client = boto3.client('s3')
    
    # if writing as a .json file
    if key[-4:]=='json':
        print("working a .json file")
        print("converting to string")
        json_object = (bytes(json.dumps(txt_object).encode('UTF-8')))
        
        print("writing to S3....")
        #dump the transcript dictionary to s3 as a json file
        s3_client.put_object(Body=json_object,
                             Bucket=bucket_name, 
                             Key=key, 
                             ContentType='application/json') #MIME type

        
    # if writing as a .txt file
    elif key[-3:]=='txt':
            s3_client.put_object(Body=txt_object,
                                 Bucket=bucket_name, 
                                 Key=key,
                                 ContentType='text/plain') #MIME type

    print("Completed writing to S3")
    
def transcribe_youtube_video(youtube_id):
    """
    given a youtube id, call the youtube transcriber and return the transcript, duration and string
    """
    from youtube_transcript_api import YouTubeTranscriptApi as yt
    
    try:
        print("getting transcript...")
        transcript = yt.get_transcript(youtube_id)
        print("calculating duration...")
        duration = get_duration_seconds(transcript)
        print("extracting text from transcript")
        text = get_text(transcript)

    except:
        print("An exception occurred for {}".format(date, youtube_id))
        transcript='error'
        duration = np.nan #null
        text='error'      
        
    return transcript, duration, text

# %% [markdown]
# ## Daily Routine: Process Latest Press Conference
# ensure the youtube link as been added to the google sheet at:
# https://docs.google.com/spreadsheets/d/1eKGoGjkvzLmoxH9mK9UGGQXWECCV4qWWCl0QKsj87cE/edit?usp=sharing
#
#
# declare the date below

# %%
date = '20210809'

# %% [markdown]
# ### Transcribe the latest video
# This will return 3 things:
# - the transcript (with timestamps)
# - the duration of the press conference
# - a string (or text) of the transcription

# %%
# import the latest youtube ID (from googlesheet referenced above)
JSON_KEY = '/Users/liampearson/Downloads/covid19data-321603-3d98ddb02134.json'
SHEET_NAME = 'youtube_ids'
BUCKET_NAME = 'covid19-au-press-conferences'

sheet = authenticate_gsheet(JSON_KEY, SHEET_NAME)

#import the youtube id's
df = import_gsheet(sheet)

#get the youtube id and link
youtube_id = df[df['date']==date]['id'].tolist()[0]
youtube_link = df[df['date']==date]['link'].tolist()[0]

print("youtube id for {} is {}".format(date, youtube_id))

#call the youtube transcriber
transcript, duration, text = transcribe_youtube_video(youtube_id)
# Out:
# youtube id for 20210809 is EvRhxnmPCo0
# getting transcript...
# calculating duration...
# extracting text from transcript

# %% [markdown]
# ##  add to S3 bucket as .txt file

# %%
add_file_to_s3(bucket_name = BUCKET_NAME, 
               key = 'nsw/text/{}_nsw_press_conference.txt'.format(date),
               txt_object = text)
# Out:
# starting up S3 client...
# Completed writing to S3

# %% [markdown]
# ### Now get the big json file (all transcriptions)
# then:
# - append the latest data to it
# - push back to S3

# %%
import ast
#download from S3
print("downloading json from S3")
bytes_object = download_s3_file_to_memory(BUCKET_NAME, 'nsw/json/nswtranscriptions.json')

#convert to dictionary
print("Converting downloaded bytes to dictionary")
transcriptions_dict = ast.literal_eval(bytes_object.decode('utf-8'))

# create latest entry
print("Creating new entry (dictionary)")
new_dict = {'link':youtube_link,
                  'id':youtube_id,
                  'duration_seconds':duration,
                  'transcript': transcript,
                  'text':text
                 }

# add it to the dictionary
print("appending to large dictionary of past entries")
transcriptions_dict[date] = new_dict

#send back to S3
print("sending back to S3...")
add_file_to_s3(bucket_name = BUCKET_NAME, 
               key = 'nsw/json/nswtranscriptions.json'.format(date),
               txt_object = transcriptions_dict)

print("Complete")
# Out:
# downloading json from S3
# Converting downloaded bytes to dictionary
# Creating new entry (dictionary)
# appending to large dictionary of past entries
# sending back to S3...
# starting up S3 client...
# working a .json file
# converting to string
# writing to S3....
# Completed writing to S3
# Complete

# %%
def manually_import_text(text_path):
    with open(text_path, 'r') as file:
        data = file.read().replace('\n', '')
        
    return data

text_path = '/Users/liampearson/Downloads/20210718.txt'

data = manually_import_text(text_path)
data = data.replace("\ufeff", "")

date = '20210718'
BUCKET_NAME = 'covid19-au-press-conferences'


add_file_to_s3(bucket_name = BUCKET_NAME, 
               key = 'nsw/text/{}_nsw_press_conference.txt'.format(date),
               txt_object = data)
# Out:
# starting up S3 client...
# Completed writing to S3
